# %%
import os
with open('tokens_and_api.txt', 'r') as file:
    exec(file.read())

# %%
#set Spark config for the container and storage account
spark.conf.set(
    "fs.azure.account.auth.type.newadbprojektkakastorage.dfs.core.windows.net", "SAS"
)

# %%
spark.conf.set(
    "fs.azure.sas.token.provider.type.newadbprojektkakastorage.dfs.core.windows.net",
    "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider"
)

# %%
spark.conf.set(
    "fs.azure.sas.fixed.token.newadbprojektkakastorage.dfs.core.windows.net",
    sas_token  
)

# %%
df = spark.read.format("csv").option("header", True).load(
    "abfss://data@newadbprojektkakastorage.dfs.core.windows.net/flights.csv"
)
display(df.limit(10))
