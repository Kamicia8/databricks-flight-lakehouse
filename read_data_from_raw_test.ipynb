# %%
sas_token = "sp=rcwl&st=2025-12-09T20:54:22Z&se=2025-12-10T05:09:22Z&spr=https&sv=2024-11-04&sr=c&sig=y5Db4AWdt1QKiZuzP08VLQJjCSu%2FEaIRMxlZviX%2FlY8%3D"

# %%
#set Spark config for the container and storage account
spark.conf.set(
    "fs.azure.account.auth.type.adbprojektkakastorage.dfs.core.windows.net", "SAS"
)

# %%
spark.conf.set(
    "fs.azure.sas.token.provider.type.adbprojektkakastorage.dfs.core.windows.net",
    "org.apache.hadoop.fs.azurebfs.sas.FixedSASTokenProvider"
)

# %%
spark.conf.set(
    "fs.azure.sas.fixed.token.adbprojektkakastorage.dfs.core.windows.net",
    sas_token
)

# %%
df = spark.read.format("csv").option("header", True).load(
    "abfss://raw@adbprojektkakastorage.dfs.core.windows.net/flights.csv"
)
display(df.limit(10))
